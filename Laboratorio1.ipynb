# %% [markdown]
# <h1><center>Laboratorio 1: Git 👾</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Otoño 2023</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesores: Pablo Badilla, Ignacio Meza D.
# - Auxiliar: Sebastián Tinoco
# - Ayudante: Diego Cortez

# %% [markdown]
# ### Equipo: SUPER IMPORTANTE - notebooks sin nombre no serán revisados
#
# - Nombre de alumno 1: Diego Dominguez
# - Nombre de alumno 2: Arturo Lazcano

# %% [markdown]
# ### **Link de repositorio de GitHub:** https://github.com/DDominguezD/MDS7202

# %% [markdown]
# ## Reglas:
#
# - Fecha de entrega: 6 días desde la publicación, 3 días de atraso con 1 punto de descuento c/u. Pueden utilizar días bonus sin descuento.
# - **Grupos de 2 personas**.
# - **Ausentes** deberán realizar la actividad solos.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Pueden usar cualquer material del curso que estimen conveniente.
# - Asistencia obligatoria a instrucciones del lab (viernes 16.15). Luego, pueden quedarse trabajando en las salas o irse.

# %% [markdown]
# ## Objetivos del lab:
#
#
# - Conocer los elementos básicos que conformar `Git`
# - Clonar repositorios
# - Identificar ramas de un repositorio
# - Reconocer y solucionar problemas entre ramas
# - Subir cambios a un repositorio

# %% [markdown]
# ## Parte 1: Conocimiento Teórico (2 pts)

# %% [markdown]
# Responda las siguientes preguntas (0.2 pts c/u):
#
# 1. ¿Qué es `Git` y cómo se relaciona con el control de versiones?
#
# 2. Nombre y explique 3 diferencias entre `Git` y `Github`.
#
# 3. ¿Qué es un `hash` y cómo se representa en un `commit`? De un ejemplo.
#
# 4. ¿Que elementos componen a la estructura de datos de `Git`?
#
# 5. ¿Que comandos de `Git` sirven para crear un repositorio y hacer seguimiento a cambios en los archivos?

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# 1. Git es un software creado para control de versiones, más específicamente, control de versiones distribuidos.
# Sirve para ir guardando y actualizando archivos en un repositorio que pueden ser trabajados tanto por una persona como un equipo de ellas.
#
# 2.
# - Git es un sistema de control de versiones distribuidos mientras que github solo aloja archivos basados en web
# - Git se usa mediante una linea de comandos mientras que github es más una interfaz web (más intuitivo si no se conoce el lenguaje de git).
# - Git crea un repositorio local para rastrear cambios en archivos locales mientras que github sirve para ir subiendo copias de los repositorios de Git.
#
# 3. Un hash es un código único para identificar los cambios, cuando se hicieron estos y quien los ha hecho. Son de 40 carácteres y pueden apuntar a un blob, un commit o un árbol.
#
# 4. Como se mencionó en la pregunta anterior, los elementos que componen la estructura de datos de Git son los blob, commmit y árboles. Se puede pensar el árbol como una estructura que almacena directorios para los blob mientras que los commit son "capturas" del historial que registra cambios en archivos.
#
# 5.
# * git init `repositorio_nuevo` es el comnado que permite crear repositorios donde repositorio_nuevo es el nombre que queremos darle.
# * git log es el comando a usar si se quiere observar el registro de cambios.

# %% [markdown]
# Responda si las siguientes afirmaciones son Verdaderas (V) o Falsas (F). Justifique en **cualquiera** de los casos (0.2 pts c/u):
#
#
# 6. `Git` siempre resuelve automáticamente los problemas de lineas al hacer merge entre diferentes ramas.
# 7. Ejecutar `git pull` sobre un repositorio es equivalente a ejecutar `git clone`.
# 8. Cada miembro del equipo trabaja en la misma copia del código fuente usando `Git`.
# 9. En `Git` es posible deshacer cambios y volver a versiones anteriores del código.
# 10. El comando `git commit` se utiliza para enviar cambios al repositorio remoto.

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# 6. Falso, es posible que existan colisiones en el trabajo pues hay incoherencias en distintas ramas de este. Estos conflictos deben ser resueltos a mano.
#
# 7. Falso, el comando git clone lo que hace es inicializar un repositorio, mientras que git pull es guiado más a la comunicación entre repositorios, siendo esta útil para obtener el registro de cambios de un repositorio remoto.
#
# 8. Falso, cada miembro del equipo tiene su propia copia local del repositorio, en la cual pueden hacer cambios independientes sin afectar el trabajo de los demás miembros.
#
# 9. Verdadero, comandos útiles para esto son git reset HEAD, git checkout -- folder/file, git checkout commit-hash folder/file o git checkout commit-hash.
#
# 10. Falso, el comando sí sirve para enviar cambios pero dentro del repositorio local.

# %% [markdown]
# ## Parte 2: Creando una presentación personal (2 pts)

# %% [markdown]
# Para empezar a "*soltar las manos*" con `Git`, se les encomienda crear un repositorio con una presentación personal. El repositorio debe contener un breve resumen de quienes son ustedes, sus gustos, experiencias, y cualquier otro detalle interesante que ustedes consideren relevante.
#
# Para realizar esto, deben seguir los siguientes pasos:
#
# 1. Contar con una cuenta de github (1 por persona)
# 2. Crear un repositorio con su nombre de usuario
# 3. Crear y modificar un archivo `readme.md` con la información que ustedes deseen compartir.
#
# A modo de ejemplo, pueden guiarse por esta *suculenta* [presentación](https://github.com/pbadillatorrealba/pbadillatorrealba).
#
# *Hint: Una buena opción es usar templates de presentación personal que encuentren en Google, como los que ofrece este [sitio](https://durgeshsamariya.github.io/awesome-github-profile-readme-templates/#/)*.
#
# **Entregable:**
#
# Enlace al repositorio con la presentación personal.
#
# IMPORTANTE: DEBEN ADJUNTAR UN ENLACE POR PERSONA

# %% [markdown]
# <code>Link Presentacion 1:</code> https://github.com/DDominguezD/DDominguezD
#
# <code>Link Presentacion 2:</code> https://github.com/ALazcanoG/ALazcanoG

# %% [markdown]
# ## Parte 3: Trabajando sobre un repositorio externo (2 pts)

# %% [markdown]
# Tras muchos dolores de cabeza, un grupo de entusiastas académicos decidieron aprender sobre `Git` y así trabajar colaborativamente de forma más ordenada y eficiente. Después de una infinidad de intentos y aprender de sus errores "*a la mala*", los académicos lograron levantar un [repositorio](https://github.com/MDS7202/lab1) en `Github`. Usando el repositorio de los académicos, responda las siguientes preguntas (incluya también los comandos en `Git` ocupados):

# %% [markdown]
# 1. Clone el repositorio a su ambiente local. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:
#
# git clone https://github.com/MDS7202/lab1.git
# </code>

# %% [markdown]
# 2. Inspeccione brevemente el repositorio: ¿Cual es el objetivo del proyecto? Explique brevemente la estructura del proyecto, asi como también de cada componente que lo conforma. (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# El objetivo del proyecto consiste en una función que recibe como entrada el string de un animal e imprime el sonido que hace este si consigue reconocerlo.
# Este proyecto contiene tres archivos: animales.py, main.py y readme.md
#
# En el archivo "animales.py" se encuentra la función que imprime el el sonido del animal cuando el input correponde a un gato, un perro o un zorro. En el caso de ser otro animal, aparece un error debido a que el animal no fue reconocido.
#
# Luego en "main.py" se importa la funcion animales del archivo animales.py para usarla en un entorno interactivo.
# Por último, el archivo readme.md contine una breve descripción del proyecto y una imagen de animales.

# %% [markdown]
# 3. Identifique los últimos cambios al repositorio, reconociendo las principales ramas de trabajo. ¿Son informativos los `commit` realizados? (0.25 pts)
# *Hint: Se recomienda usar los argumentos `all`, `graph` y `decorate`*

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# Hubieron cuatro commits realizados, el comando para visualizarlos se encuentra en la siguiente imagen:
#
# ![commits.PNG](data:image/png;base64,...)
#
#
# Podemos observar que los cuatro commits poseen un comentario asociado a la tarea que se realizó al guardar dicho commit, no obstante, consideramos que el primer commit no tiene una descripción informativa pertinente al trabajo que se estuvo realizando, pero el resto si entrega información valiosa al lector acerca de las tareas realizadas en el proyecto.
#
# Luego con el comando <code>git branch -a </code> obtenemos las siguientes tres ramas: <code>fix-ifs</code>, <code>main</code> y <code>new_features</code>.

# %% [markdown]
# 4. Uno de los académicos se da cuenta que la rama principal de trabajo no se ejecuta correctamente para todos los argumentos. Señale el error en el código e identifique a la persona que lo cometió usando `git blame` (0.25 pts)
#
# *Hint: Le puede ser útil esta [documentación](https://www.atlassian.com/es/git/tutorials/inspecting-a-repository/git-blame).*

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# El error está en el archivo animales.py en la función animales. Esta tiene el error de usar solo "if" para cada caso. Esto causa que la línea de código con "else" esté asociada al último if y no a todos los casos anteriores. Esto se soluciona cambiando estos ifs por elif.
# La persona que escribió ese código original (que contiene errores) fue mezosky.
#
# ![blame.PNG](data:image/png;base64,...)

# %% [markdown]
# 5. Busque los siguientes `commit`:
#
# - `c8b1a62d7299552b0654f930d695b33109214111`
# - `362fe21ee44f53ee944cee4ba484600308f83d78`
# - `25543a3baf77292baf849726784ca005473acab1`
#
# ¿Qué diferencias existen entre cada uno? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# - `c8b1a62d7299552b0654f930d695b33109214111`
# ![comit1.png](data:image/png;base64,...)
#
# - `362fe21ee44f53ee944cee4ba484600308f83d78`
# ![comit2.PNG](data:image/png;base64,...)
#
# - `25543a3baf77292baf849726784ca005473acab1`
# ![comit3.PNG](data:image/png;base64,...)
#
#
# Se puede observar que en el commit <code>c8b1a62</code> se define la función de animales en el archivo main.py, el cual ya tenía un codigo interactivo para imprimir el sonido del animal. Luego en el commit <code>362fe21</code>, se separa el proyecto en modulos, guardando la función animales en el archivo animales.py
#
# Mientras que en el commit <code>25543a3</code>, se arregla el problema de los ifs que tenía el código anterior y causaba que la rama principal de trabajo no se ejecute correctamente para todos los argumentos.

# %% [markdown]
# 6. Realice una `merge` de la rama `fix-ifs` con la rama `main` y describa lo que ocurre. ¿Qué parte del código podría estar ocasionando esto? (0.25 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# Al intentar usar merge en las ramas main y fix-ifs, nos encontramos con un error de conflicto que git espera que solucionemos a mano para poder realizar el merge de manera correcta. Este error se puede apreciar en la siguiente imagen:
#
# ![merge.PNG](data:image/png;base64,...)
#
# El archivo main.py de la rama main entra en conflicto con el archivo main.py de la rama fix-ifs, que es la que queremos fusionar, debido a que poseen diferentes líneas de código.

# %% [markdown]
# 7. Cree una rama nueva y proponga una solución al problema anterior, adjuntando el código corregido y señalando las líneas modificadas. (0.5 pts)

# %% [markdown]
# <code>Escriba sus respuestas acá:</code>
#
# Primeramente, creamos una nueva rama de ejemplo para solucionar el probelma, esta recibe el nombre de nueva_rama.
# Luego de movernos a esta nueva rama, editamos el archivo animales.py para que tenga las modificaciones que había recibido en la rama fix-ifs, es decir, cambiar ifs por elifs en el código de la función.
# Después, añadimos este archivo animales.py modificado a la nueva rama creada e hicimos el merge con la rama main para así tener una versión final o actualizada de lo que es este proyecto.
# Así, hicimos el commit correspondiente con un comentario informativo para solucionar el probema presentado en el punto anterior.
# A continuación se muestran los pasos explicados en el cmd de windows:
#
# ![p7_1.png](data:image/png;base64,...)
#
# ![p7_2.png](data:image/png;base64,...)
#
# Por último, a modo de comprobar los cambios, utilizamos el comando git blame para verificar que otra entidad (nosotros) modificó las líneas de códigos correspondientes.
# ![p7_3.PNG](data:image/png;base64,...)

# %% [markdown]
# ## Fin

# %% [markdown]
# Eso ha sido todo por ahora!! Esperamos que este laboratorio les haya gustado y servido para trabajar con `Git`. Recuerden los dias de plazo que tienen disponibles y que ante cualquier duda no duden en contactar al equipo docente.
#
# Nos vemos!!
#
# <img src=https://media.tenor.com/OYLdav9k9LkAAAAd/kitty-cat.gif height=300>
